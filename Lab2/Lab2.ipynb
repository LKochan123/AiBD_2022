# %% [markdown]
# # Łukasz Kochańczyk, gr. 4

# %%
import warnings
warnings.filterwarnings('ignore')

import psycopg2 as pg
import pandas as pd

connection = pg.connect(host='pgsql-196447.vipserv.org', port=5432, dbname='wbauer_adb', user='wbauer_adb', password='adb2020')

# %% [markdown]
# #### 1)

# %%
df = pd.read_sql('SELECT count(*) FROM category', con=connection)
df['count'][0]
# Out:
# 16

# %% [markdown]
# #### 2)

# %%
df = pd.read_sql('SELECT name FROM category ORDER BY name ASC', con=connection)
df
# Out:
#            name
# 0        Action
# 1     Animation
# 2      Children
# 3      Classics
# 4        Comedy
# 5   Documentary
# 6         Drama
# 7        Family
# 8       Foreign
# 9         Games
# 10       Horror
# 11        Music
# 12          New
# 13       Sci-Fi
# 14       Sports
# 15       Travel

# %% [markdown]
# #### 3)

# %%
df = pd.read_sql('SELECT MIN(release_year), MAX(release_year) FROM film', con=connection)
df
# Wszystkie filmy są z 2006 roku
# Out:
#     min   max
# 0  2006  2006

# %% [markdown]
# #### 4)

# %%
df = pd.read_sql("SELECT count(*) FROM rental WHERE rental_date BETWEEN '2005-07-01' AND '2005-08-01'", con=connection)
df['count'][0]
# Out:
# 6709

# %% [markdown]
# #### 5)

# %%
df = pd.read_sql("SELECT count(*) FROM rental WHERE rental_date BETWEEN '2010-01-01' AND '2011-02-01'", con=connection)
df['count'][0]
# Out:
# 0

# %% [markdown]
# #### 6)

# %%
df = pd.read_sql('SELECT MAX(amount) from payment', con=connection)
df['max'][0]
# Out:
# 11.99

# %% [markdown]
# #### 7)

# %%
cols_to_show = 'first_name, last_name, country'
countries = "'Poland', 'Nigeria', 'Bangladesh'"

df = pd.read_sql(f"SELECT {cols_to_show} FROM customer, country WHERE country IN ({countries})", con=connection)
df
# Out:
#      first_name last_name     country
# 0         Jared       Ely  Bangladesh
# 1         Jared       Ely     Nigeria
# 2         Jared       Ely      Poland
# 3          Mary     Smith  Bangladesh
# 4          Mary     Smith     Nigeria
# ...         ...       ...         ...
# 1792       Wade  Delvalle     Nigeria
# 1793       Wade  Delvalle      Poland
# 1794     Austin   Cintron  Bangladesh
# 1795     Austin   Cintron     Nigeria
# 1796     Austin   Cintron      Poland
#
# [1797 rows x 3 columns]

# %% [markdown]
# #### 8)

# %%
df = pd.read_sql('SELECT * FROM staff, address', con = connection)
df
# Out:
#       staff_id first_name last_name  address_id                         email  \
# 0            1       Mike   Hillyer           3  Mike.Hillyer@sakilastaff.com
# 1            2        Jon  Stephens           4  Jon.Stephens@sakilastaff.com
# 2            1       Mike   Hillyer           3  Mike.Hillyer@sakilastaff.com
# 3            2        Jon  Stephens           4  Jon.Stephens@sakilastaff.com
# 4            1       Mike   Hillyer           3  Mike.Hillyer@sakilastaff.com
# ...        ...        ...       ...         ...                           ...
# 1201         2        Jon  Stephens           4  Jon.Stephens@sakilastaff.com
# 1202         1       Mike   Hillyer           3  Mike.Hillyer@sakilastaff.com
# 1203         2        Jon  Stephens           4  Jon.Stephens@sakilastaff.com
# 1204         1       Mike   Hillyer           3  Mike.Hillyer@sakilastaff.com
# 1205         2        Jon  Stephens           4  Jon.Stephens@sakilastaff.com
#
# ...

# %% [markdown]
# #### 9)

# %%
col_result = 'first_name, last_name, email, country'
df = pd.read_sql(f"SELECT {col_result} FROM staff, country WHERE country IN ('Argentina', 'Spain')", con=connection)
print(f'W tych krajach mieszka {len(df)} pracowników')
df
# Out:
# W tych krajach mieszka 4 pracowników
#   first_name last_name                         email    country
# 0       Mike   Hillyer  Mike.Hillyer@sakilastaff.com  Argentina
# 1       Mike   Hillyer  Mike.Hillyer@sakilastaff.com      Spain
# 2        Jon  Stephens  Jon.Stephens@sakilastaff.com  Argentina
# 3        Jon  Stephens  Jon.Stephens@sakilastaff.com      Spain

# %% [markdown]
# #### 10)

# %%
#Dokończyć

df = pd.read_sql("SELECT * FROM customer", con=connection)
df
# Out:
#      customer_id  store_id first_name  last_name  \
# 0            524         1      Jared        Ely
# 1              1         1       Mary      Smith
# 2              2         1   Patricia    Johnson
# 3              3         1      Linda   Williams
# 4              4         2    Barbara      Jones
# ..           ...       ...        ...        ...
# 594          595         1   Terrence  Gunderson
# 595          596         1    Enrique   Forsythe
# 596          597         1    Freddie     Duggan
# 597          598         1       Wade   Delvalle
# 598          599         2     Austin    Cintron
#
#                                      email  address_id  activebool  \
# 0             jared.ely@sakilacustomer.org         530        True
# 1            mary.smith@sakilacustomer.org           5        True
# 2      patricia.johnson@sakilacustomer.org           6        True
# 3        linda.williams@sakilacustomer.org           7        True
# ...

# %% [markdown]
# #### 11)

# %%
#Dokończyć
df = pd.read_sql(f"SELECT name FROM category", con=connection)
df
# Out:
#            name
# 0        Action
# 1     Animation
# 2      Children
# 3      Classics
# 4        Comedy
# 5   Documentary
# 6         Drama
# 7        Family
# 8       Foreign
# 9         Games
# 10       Horror
# 11        Music
# 12          New
# 13       Sci-Fi
# 14       Sports
# 15       Travel

# %% [markdown]
# #### 12)

# %%
condition = "first_name = 'Olympia' AND last_name = 'Pfeiffer' OR first_name = 'Julia' AND last_name = 'Zellweger' OR first_name = 'Ellen' AND last_name = 'Presley'"
df = pd.read_sql(f"""
                SELECT title FROM film where film_id IN
                (SELECT film_id FROM film_actor WHERE actor_id IN
                (SELECT actor_id FROM actor WHERE {condition}))""", con=connection)
df
# Out:
#                 title
# 0      Express Lonely
# 1     Bilko Anonymous
# 2    Effect Gladiator
# 3   Contact Anonymous
# 4         Others Soup
# ..                ...
# 64      Hanky October
# 65    Tourist Pelican
# 66   Detective Vision
# 67       None Spiking
# 68     Homeward Cider
#
# [69 rows x 1 columns]
